# %%
import numpy as np
import pandas as pd

# %%
basketball_data =pd.read_html('https://en.wikipedia.org/wiki/NBA_All-Star_Game#All-Star_Game_results')
basketball_data
# Out:
# [  National Basketball Association All-Star Game  \
#  0                                           NaN
#  1                                     Frequency
#  2                                   Inaugurated
#  3                                   Most recent
#  4                                Previous event
#  5                                    Next event
#  6                                  Participants
#  7                                  Organized by
#  8                        2023 NBA All-Star Game
#
#       National Basketball Association All-Star Game.1
#  0                                                NaN
#  1                                             Annual
#  2                                               1951
#  3                                        2023 (Utah)
#  4                                   2022 (Cleveland)
#  5                                     2024 (Indiana)
#  6  Eastern Conference and Western Conference All-...
# ...

# %%
basketball_data.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 basketball_data.columns
#
# AttributeError: 'list' object has no attribute 'columns'

# %%
separate = pd.read_html('https://en.wikipedia.org/wiki/NBA_All-Star_Game#All-Star_Game_results')
pd.concat([separate[0],separate[1]])
# Out:
#   National Basketball Association All-Star Game  \
# 0                                           NaN
# 1                                     Frequency
# 2                                   Inaugurated
# 3                                   Most recent
# 4                                Previous event
# 5                                    Next event
# 6                                  Participants
# 7                                  Organized by
# 8                        2023 NBA All-Star Game
#
#      National Basketball Association All-Star Game.1  \
# 0                                                NaN
# 1                                             Annual
# 2                                               1951
# 3                                        2023 (Utah)
# 4                                   2022 (Cleveland)
# 5                                     2024 (Indiana)
# 6  Eastern Conference and Western Conference All-...
# ...
